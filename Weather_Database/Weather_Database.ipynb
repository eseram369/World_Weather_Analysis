# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 769

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | privokzalnyy
# City not found. Skipping
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | iquique
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | nhamunda
# Processing Record 8 of Set 1 | poum
# Processing Record 9 of Set 1 | mahibadhoo
# Processing Record 10 of Set 1 | arlit
# Processing Record 11 of Set 1 | mosalsk
# Processing Record 12 of Set 1 | quatre cocos
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping
# Processing Record 14 of Set 1 | nanfeng
# Processing Record 15 of Set 1 | nanyang
# Processing Record 16 of Set 1 | yar-sale
# Processing Record 17 of Set 1 | lesnica
# Processing Record 18 of Set 1 | isangel
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | adrar
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | viedma
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | perth
# Processing Record 30 of Set 1 | san patricio
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | bouafle
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | vao
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | mbekenyera
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | vestmannaeyjar
# Processing Record 39 of Set 1 | mount gambier
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | boueni
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | innisfail
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | tumannyy
# City not found. Skipping
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | andenes
# Processing Record 48 of Set 1 | flinders
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | kandrian
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | kazalinsk
# City not found. Skipping
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | omsukchan
# Processing Record 6 of Set 2 | chumikan
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | tilichiki
# Processing Record 9 of Set 2 | kamenskoye
# City not found. Skipping
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | debre sina
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | ilovlya
# Processing Record 15 of Set 2 | tubruq
# City not found. Skipping
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 18 of Set 2 | esil
# Processing Record 19 of Set 2 | bethel
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | nizwa
# Processing Record 22 of Set 2 | great yarmouth
# Processing Record 23 of Set 2 | bougouni
# Processing Record 24 of Set 2 | grand river south east
# City not found. Skipping
# Processing Record 25 of Set 2 | yarmouth
# Processing Record 26 of Set 2 | olinda
# Processing Record 27 of Set 2 | lorengau
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | camacha
# Processing Record 33 of Set 2 | bendigo
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | kropotkin
# Processing Record 36 of Set 2 | korla
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | bakel
# Processing Record 39 of Set 2 | ust-kamchatsk
# City not found. Skipping
# Processing Record 40 of Set 2 | upata
# Processing Record 41 of Set 2 | khor
# Processing Record 42 of Set 2 | phan rang
# City not found. Skipping
# Processing Record 43 of Set 2 | shimoda
# Processing Record 44 of Set 2 | puerto el triunfo
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | macapa
# Processing Record 48 of Set 2 | elk plain
# Processing Record 49 of Set 2 | kibray
# Processing Record 50 of Set 2 | le port
# Processing Record 1 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 2 of Set 3 | panguna
# Processing Record 3 of Set 3 | darnah
# Processing Record 4 of Set 3 | fonte boa
# Processing Record 5 of Set 3 | gushikawa
# Processing Record 6 of Set 3 | ketchikan
# Processing Record 7 of Set 3 | buala
# Processing Record 8 of Set 3 | fasa
# Processing Record 9 of Set 3 | svetlogorsk
# Processing Record 10 of Set 3 | fatikchhari
# City not found. Skipping
# Processing Record 11 of Set 3 | vostok
# Processing Record 12 of Set 3 | ayan
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | airai
# Processing Record 16 of Set 3 | astoria
# Processing Record 17 of Set 3 | ninghai
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | chegdomyn
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | constitucion
# Processing Record 22 of Set 3 | malinovoye ozero
# Processing Record 23 of Set 3 | cairns
# Processing Record 24 of Set 3 | veraval
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | rungata
# City not found. Skipping
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | fort nelson
# Processing Record 30 of Set 3 | albany
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | elbistan
# Processing Record 34 of Set 3 | eston
# Processing Record 35 of Set 3 | daru
# Processing Record 36 of Set 3 | buchanan
# Processing Record 37 of Set 3 | congonhas
# Processing Record 38 of Set 3 | buin
# Processing Record 39 of Set 3 | amazar
# Processing Record 40 of Set 3 | birin
# Processing Record 41 of Set 3 | chiradzulu
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | saint-georges
# Processing Record 44 of Set 3 | dinard
# Processing Record 45 of Set 3 | hithadhoo
# Processing Record 46 of Set 3 | korhogo
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | shanting
# Processing Record 49 of Set 3 | sorsk
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping
# Processing Record 1 of Set 4 | tomatlan
# Processing Record 2 of Set 4 | flagstaff
# Processing Record 3 of Set 4 | mortka
# Processing Record 4 of Set 4 | boo
# Processing Record 5 of Set 4 | naifaru
# Processing Record 6 of Set 4 | emba
# Processing Record 7 of Set 4 | vila do maio
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | attawapiskat
# City not found. Skipping
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | champerico
# Processing Record 12 of Set 4 | seybaplaya
# Processing Record 13 of Set 4 | kedrovyy
# Processing Record 14 of Set 4 | teofilo otoni
# Processing Record 15 of Set 4 | villa de reyes
# Processing Record 16 of Set 4 | yakeshi
# Processing Record 17 of Set 4 | burica
# City not found. Skipping
# Processing Record 18 of Set 4 | noumea
# Processing Record 19 of Set 4 | karaul
# City not found. Skipping
# Processing Record 20 of Set 4 | port macquarie
# Processing Record 21 of Set 4 | wewak
# Processing Record 22 of Set 4 | itarema
# Processing Record 23 of Set 4 | dikson
# Processing Record 24 of Set 4 | cap-aux-meules
# Processing Record 25 of Set 4 | iracoubo
# Processing Record 26 of Set 4 | sigli
# Processing Record 27 of Set 4 | necochea
# Processing Record 28 of Set 4 | boyolangu
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | kisangani
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | lavrentiya
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | maceio
# Processing Record 36 of Set 4 | dunedin
# Processing Record 37 of Set 4 | port hope
# Processing Record 38 of Set 4 | tazovskiy
# Processing Record 39 of Set 4 | mehamn
# Processing Record 40 of Set 4 | carutapera
# Processing Record 41 of Set 4 | dujuma
# City not found. Skipping
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | padang
# Processing Record 44 of Set 4 | ikare
# Processing Record 45 of Set 4 | pokaran
# Processing Record 46 of Set 4 | bredasdorp
# Processing Record 47 of Set 4 | barbar
# City not found. Skipping
# Processing Record 48 of Set 4 | hay river
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping
# Processing Record 50 of Set 4 | isla mujeres
# Processing Record 1 of Set 5 | haapiti
# Processing Record 2 of Set 5 | tucuman
# Processing Record 3 of Set 5 | carnot
# Processing Record 4 of Set 5 | dzhusaly
# City not found. Skipping
# Processing Record 5 of Set 5 | lebu
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | nikolskiy
# Processing Record 12 of Set 5 | fortuna
# Processing Record 13 of Set 5 | kholodnyy
# Processing Record 14 of Set 5 | mutoko
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | yaan
# Processing Record 17 of Set 5 | los llanos de aridane
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | buariki
# City not found. Skipping
# Processing Record 20 of Set 5 | nikolskoye
# Processing Record 21 of Set 5 | tatvan
# Processing Record 22 of Set 5 | harper
# Processing Record 23 of Set 5 | victoria point
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping
# Processing Record 25 of Set 5 | barra do garcas
# Processing Record 26 of Set 5 | kaitangata
# Processing Record 27 of Set 5 | esperance
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | umzimvubu
# City not found. Skipping
# Processing Record 31 of Set 5 | nalvo
# Processing Record 32 of Set 5 | diego de almagro
# Processing Record 33 of Set 5 | atar
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | mogadishu
# Processing Record 36 of Set 5 | baculin
# Processing Record 37 of Set 5 | san isidro
# Processing Record 38 of Set 5 | eyl
# Processing Record 39 of Set 5 | tarnobrzeg
# Processing Record 40 of Set 5 | grindavik
# Processing Record 41 of Set 5 | aleksandrovsk
# Processing Record 42 of Set 5 | meulaboh
# Processing Record 43 of Set 5 | axim
# Processing Record 44 of Set 5 | sept-iles
# Processing Record 45 of Set 5 | kupino
# Processing Record 46 of Set 5 | desaguadero
# Processing Record 47 of Set 5 | tinyahuarco
# Processing Record 48 of Set 5 | carnarvon
# Processing Record 49 of Set 5 | saint-pierre
# Processing Record 50 of Set 5 | kankon
# Processing Record 1 of Set 6 | seddon
# Processing Record 2 of Set 6 | agirish
# Processing Record 3 of Set 6 | praia da vitoria
# Processing Record 4 of Set 6 | bayevo
# Processing Record 5 of Set 6 | taree
# Processing Record 6 of Set 6 | wentzville
# Processing Record 7 of Set 6 | altay
# Processing Record 8 of Set 6 | tongzi
# Processing Record 9 of Set 6 | vani
# Processing Record 10 of Set 6 | marquette
# Processing Record 11 of Set 6 | kidal
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | jiayuguan
# Processing Record 15 of Set 6 | buraydah
# Processing Record 16 of Set 6 | oranjemund
# Processing Record 17 of Set 6 | boguchany
# Processing Record 18 of Set 6 | price
# Processing Record 19 of Set 6 | rongcheng
# Processing Record 20 of Set 6 | rocha
# Processing Record 21 of Set 6 | kaeo
# Processing Record 22 of Set 6 | grand gaube
# Processing Record 23 of Set 6 | vila franca do campo
# Processing Record 24 of Set 6 | lixourion
# Processing Record 25 of Set 6 | nagato
# Processing Record 26 of Set 6 | port blair
# Processing Record 27 of Set 6 | geldern
# Processing Record 28 of Set 6 | kulhudhuffushi
# Processing Record 29 of Set 6 | tateyama
# Processing Record 30 of Set 6 | ballina
# Processing Record 31 of Set 6 | srandakan
# Processing Record 32 of Set 6 | nishihara
# Processing Record 33 of Set 6 | tarudant
# City not found. Skipping
# Processing Record 34 of Set 6 | tarnos
# Processing Record 35 of Set 6 | agnibilekrou
# Processing Record 36 of Set 6 | diphu
# Processing Record 37 of Set 6 | najran
# Processing Record 38 of Set 6 | khash
# Processing Record 39 of Set 6 | puerto ayacucho
# Processing Record 40 of Set 6 | ixtapa
# Processing Record 41 of Set 6 | atbasar
# Processing Record 42 of Set 6 | antalaha
# Processing Record 43 of Set 6 | esfarayen
# Processing Record 44 of Set 6 | port hedland
# Processing Record 45 of Set 6 | nehe
# Processing Record 46 of Set 6 | portree
# Processing Record 47 of Set 6 | las palmas
# Processing Record 48 of Set 6 | cidreira
# Processing Record 49 of Set 6 | saint-francois
# Processing Record 50 of Set 6 | la ronge
# Processing Record 1 of Set 7 | barcelona
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | jensen beach
# Processing Record 4 of Set 7 | surgut
# Processing Record 5 of Set 7 | emporia
# Processing Record 6 of Set 7 | torbay
# Processing Record 7 of Set 7 | tautira
# Processing Record 8 of Set 7 | ixhuatan
# Processing Record 9 of Set 7 | stipsi
# City not found. Skipping
# Processing Record 10 of Set 7 | okitipupa
# Processing Record 11 of Set 7 | victoria
# Processing Record 12 of Set 7 | conceicao do araguaia
# Processing Record 13 of Set 7 | krasnoselkup
# Processing Record 14 of Set 7 | saskylakh
# Processing Record 15 of Set 7 | birao
# Processing Record 16 of Set 7 | sangar
# Processing Record 17 of Set 7 | portland
# Processing Record 18 of Set 7 | plettenberg bay
# Processing Record 19 of Set 7 | kenai
# Processing Record 20 of Set 7 | san pedro
# Processing Record 21 of Set 7 | manggar
# Processing Record 22 of Set 7 | huarmey
# Processing Record 23 of Set 7 | wahran
# City not found. Skipping
# Processing Record 24 of Set 7 | ahumada
# City not found. Skipping
# Processing Record 25 of Set 7 | porto velho
# Processing Record 26 of Set 7 | nizhneyansk
# City not found. Skipping
# Processing Record 27 of Set 7 | bathsheba
# Processing Record 28 of Set 7 | acari
# Processing Record 29 of Set 7 | bata
# Processing Record 30 of Set 7 | normandin
# Processing Record 31 of Set 7 | nekrasovka
# Processing Record 32 of Set 7 | rio cuarto
# Processing Record 33 of Set 7 | samusu
# City not found. Skipping
# Processing Record 34 of Set 7 | olafsvik
# Processing Record 35 of Set 7 | prabumulih
# Processing Record 36 of Set 7 | broken hill
# Processing Record 37 of Set 7 | saint-augustin
# Processing Record 38 of Set 7 | teguise
# Processing Record 39 of Set 7 | muros
# Processing Record 40 of Set 7 | milingimbi
# City not found. Skipping
# Processing Record 41 of Set 7 | gunjur
# Processing Record 42 of Set 7 | bonnyville
# Processing Record 43 of Set 7 | kostomuksha
# Processing Record 44 of Set 7 | mwanza
# Processing Record 45 of Set 7 | magdalena
# Processing Record 46 of Set 7 | laranjeiras do sul
# Processing Record 47 of Set 7 | chapais
# Processing Record 48 of Set 7 | ondorhaan
# City not found. Skipping
# Processing Record 49 of Set 7 | mackay
# Processing Record 50 of Set 7 | twentynine palms
# Processing Record 1 of Set 8 | povenets
# Processing Record 2 of Set 8 | katherine
# Processing Record 3 of Set 8 | asyut
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | guadalupe y calvo
# Processing Record 6 of Set 8 | loukhi
# Processing Record 7 of Set 8 | port lincoln
# Processing Record 8 of Set 8 | klaksvik
# Processing Record 9 of Set 8 | ibipeba
# Processing Record 10 of Set 8 | flin flon
# Processing Record 11 of Set 8 | vardo
# Processing Record 12 of Set 8 | rorvik
# Processing Record 13 of Set 8 | port elizabeth
# Processing Record 14 of Set 8 | port-gentil
# Processing Record 15 of Set 8 | mendahara
# City not found. Skipping
# Processing Record 16 of Set 8 | anloga
# Processing Record 17 of Set 8 | ust-omchug
# Processing Record 18 of Set 8 | kaoma
# Processing Record 19 of Set 8 | ola
# Processing Record 20 of Set 8 | bokspits
# City not found. Skipping
# Processing Record 21 of Set 8 | wanning
# Processing Record 22 of Set 8 | tambacounda
# Processing Record 23 of Set 8 | meyungs
# City not found. Skipping
# Processing Record 24 of Set 8 | seoul
# Processing Record 25 of Set 8 | gokak
# Processing Record 26 of Set 8 | leshukonskoye
# Processing Record 27 of Set 8 | tome
# Processing Record 28 of Set 8 | baturaja
# Processing Record 29 of Set 8 | santa isabel do rio negro
# Processing Record 30 of Set 8 | pochutla
# Processing Record 31 of Set 8 | christchurch
# Processing Record 32 of Set 8 | clyde river
# Processing Record 33 of Set 8 | husavik
# Processing Record 34 of Set 8 | yulara
# Processing Record 35 of Set 8 | marcona
# City not found. Skipping
# Processing Record 36 of Set 8 | sambava
# Processing Record 37 of Set 8 | mecca
# Processing Record 38 of Set 8 | chato
# Processing Record 39 of Set 8 | cap malheureux
# Processing Record 40 of Set 8 | coihaique
# Processing Record 41 of Set 8 | kamenka
# Processing Record 42 of Set 8 | san luis
# Processing Record 43 of Set 8 | faanui
# Processing Record 44 of Set 8 | sentyabrskiy
# City not found. Skipping
# Processing Record 45 of Set 8 | ambulu
# Processing Record 46 of Set 8 | hall
# Processing Record 47 of Set 8 | puerto escondido
# Processing Record 48 of Set 8 | itoman
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | pisco
# Processing Record 1 of Set 9 | do rud
# City not found. Skipping
# Processing Record 2 of Set 9 | takhtamygda
# Processing Record 3 of Set 9 | teluk nibung
# Processing Record 4 of Set 9 | margate
# Processing Record 5 of Set 9 | yomitan
# City not found. Skipping
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | kailua
# Processing Record 8 of Set 9 | iquitos
# Processing Record 9 of Set 9 | galle
# Processing Record 10 of Set 9 | hambantota
# Processing Record 11 of Set 9 | kawana waters
# City not found. Skipping
# Processing Record 12 of Set 9 | zermatt
# Processing Record 13 of Set 9 | iisalmi
# Processing Record 14 of Set 9 | bureya
# Processing Record 15 of Set 9 | cuaspud
# Processing Record 16 of Set 9 | kahului
# Processing Record 17 of Set 9 | priargunsk
# Processing Record 18 of Set 9 | calderitas
# Processing Record 19 of Set 9 | zhaotong
# Processing Record 20 of Set 9 | banjar
# Processing Record 21 of Set 9 | namatanai
# Processing Record 22 of Set 9 | yura
# Processing Record 23 of Set 9 | kutum
# Processing Record 24 of Set 9 | angoche
# Processing Record 25 of Set 9 | oktyabrskoye
# Processing Record 26 of Set 9 | fagernes
# Processing Record 27 of Set 9 | quchan
# Processing Record 28 of Set 9 | tiruvallur
# Processing Record 29 of Set 9 | guerrero negro
# Processing Record 30 of Set 9 | shaoguan
# Processing Record 31 of Set 9 | matola
# Processing Record 32 of Set 9 | the valley
# Processing Record 33 of Set 9 | negombo
# Processing Record 34 of Set 9 | goldap
# Processing Record 35 of Set 9 | katsuura
# Processing Record 36 of Set 9 | ambikapur
# Processing Record 37 of Set 9 | bolungarvik
# City not found. Skipping
# Processing Record 38 of Set 9 | lianran
# Processing Record 39 of Set 9 | igrim
# Processing Record 40 of Set 9 | ewa beach
# Processing Record 41 of Set 9 | chinsali
# Processing Record 42 of Set 9 | nelson bay
# Processing Record 43 of Set 9 | puerto carreno
# Processing Record 44 of Set 9 | tabas
# Processing Record 45 of Set 9 | capreol
# Processing Record 46 of Set 9 | broome
# Processing Record 47 of Set 9 | acajutla
# Processing Record 48 of Set 9 | srednekolymsk
# Processing Record 49 of Set 9 | namibe
# Processing Record 50 of Set 9 | dharchula
# Processing Record 1 of Set 10 | lahij
# Processing Record 2 of Set 10 | la brea
# Processing Record 3 of Set 10 | whitehorse
# Processing Record 4 of Set 10 | amahai
# Processing Record 5 of Set 10 | santa ana huista
# Processing Record 6 of Set 10 | richards bay
# Processing Record 7 of Set 10 | kloulklubed
# Processing Record 8 of Set 10 | nanortalik
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | kuminskiy
# Processing Record 11 of Set 10 | tulagi
# Processing Record 12 of Set 10 | kayes
# Processing Record 13 of Set 10 | tucurui
# Processing Record 14 of Set 10 | bac lieu
# Processing Record 15 of Set 10 | faya
# Processing Record 16 of Set 10 | chulman
# Processing Record 17 of Set 10 | bubaque
# Processing Record 18 of Set 10 | yining
# Processing Record 19 of Set 10 | cumaribo
# City not found. Skipping
# Processing Record 20 of Set 10 | swellendam
# Processing Record 21 of Set 10 | ahuimanu
# Processing Record 22 of Set 10 | mugur-aksy
# Processing Record 23 of Set 10 | zhigansk
# Processing Record 24 of Set 10 | kushmurun
# Processing Record 25 of Set 10 | demba
# Processing Record 26 of Set 10 | goundam
# Processing Record 27 of Set 10 | ikalamavony
# Processing Record 28 of Set 10 | nushki
# Processing Record 29 of Set 10 | bogorodskoye
# Processing Record 30 of Set 10 | tessalit
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | tabuk
# Processing Record 33 of Set 10 | port shepstone
# Processing Record 34 of Set 10 | trat
# Processing Record 35 of Set 10 | sergeyevka
# Processing Record 36 of Set 10 | fallon
# Processing Record 37 of Set 10 | ambodifototra
# City not found. Skipping
# Processing Record 38 of Set 10 | santa cruz
# Processing Record 39 of Set 10 | dakar
# Processing Record 40 of Set 10 | vanavara
# Processing Record 41 of Set 10 | eureka
# Processing Record 42 of Set 10 | mount isa
# Processing Record 43 of Set 10 | devgarh
# Processing Record 44 of Set 10 | hervey bay
# Processing Record 45 of Set 10 | sunderland
# Processing Record 46 of Set 10 | adeje
# Processing Record 47 of Set 10 | beringovskiy
# Processing Record 48 of Set 10 | aporawan
# City not found. Skipping
# Processing Record 49 of Set 10 | jingdezhen
# Processing Record 50 of Set 10 | hobyo
# Processing Record 1 of Set 11 | magadan
# Processing Record 2 of Set 11 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 3 of Set 11 | sibolga
# Processing Record 4 of Set 11 | alexandria
# Processing Record 5 of Set 11 | caconda
# Processing Record 6 of Set 11 | nemuro
# Processing Record 7 of Set 11 | salalah
# Processing Record 8 of Set 11 | suixi
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | inhambane
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | pinega
# Processing Record 13 of Set 11 | biak
# Processing Record 14 of Set 11 | filingue
# Processing Record 15 of Set 11 | saint marys
# Processing Record 16 of Set 11 | kirkwall
# Processing Record 17 of Set 11 | stockton-on-tees
# Processing Record 18 of Set 11 | suez
# Processing Record 19 of Set 11 | santo tomas
# Processing Record 20 of Set 11 | udachnyy
# Processing Record 21 of Set 11 | omboue
# Processing Record 22 of Set 11 | kiunga
# Processing Record 23 of Set 11 | madison
# Processing Record 24 of Set 11 | tual
# Processing Record 25 of Set 11 | kindu
# Processing Record 26 of Set 11 | praia
# Processing Record 27 of Set 11 | iqaluit
# Processing Record 28 of Set 11 | ye
# City not found. Skipping
# Processing Record 29 of Set 11 | bababe
# City not found. Skipping
# Processing Record 30 of Set 11 | hihifo
# City not found. Skipping
# Processing Record 31 of Set 11 | kualakapuas
# Processing Record 32 of Set 11 | kyra
# Processing Record 33 of Set 11 | mahanoro
# Processing Record 34 of Set 11 | stoyba
# City not found. Skipping
# Processing Record 35 of Set 11 | bam
# Processing Record 36 of Set 11 | lidkoping
# Processing Record 37 of Set 11 | louisbourg
# City not found. Skipping
# Processing Record 38 of Set 11 | rawson
# Processing Record 39 of Set 11 | alofi
# Processing Record 40 of Set 11 | codrington
# Processing Record 41 of Set 11 | sinnamary
# Processing Record 42 of Set 11 | ambanja
# Processing Record 43 of Set 11 | vieste
# Processing Record 44 of Set 11 | luau
# Processing Record 45 of Set 11 | sladkovo
# Processing Record 46 of Set 11 | sumbawa
# City not found. Skipping
# Processing Record 47 of Set 11 | collie
# Processing Record 48 of Set 11 | kavaratti
# Processing Record 49 of Set 11 | torit
# Processing Record 50 of Set 11 | port hardy
# Processing Record 1 of Set 12 | zhezkazgan
# Processing Record 2 of Set 12 | san policarpo
# Processing Record 3 of Set 12 | ormos korthiou
# City not found. Skipping
# Processing Record 4 of Set 12 | cherskiy
# Processing Record 5 of Set 12 | jeremie
# Processing Record 6 of Set 12 | marsa matruh
# Processing Record 7 of Set 12 | sao joao da barra
# Processing Record 8 of Set 12 | contamana
# Processing Record 9 of Set 12 | dusti
# Processing Record 10 of Set 12 | ardmore
# Processing Record 11 of Set 12 | kununurra
# Processing Record 12 of Set 12 | okha
# Processing Record 13 of Set 12 | kyzyl-suu
# Processing Record 14 of Set 12 | aklavik
# Processing Record 15 of Set 12 | belmonte
# Processing Record 16 of Set 12 | bismil
# Processing Record 17 of Set 12 | nokaneng
# Processing Record 18 of Set 12 | pangnirtung
# Processing Record 19 of Set 12 | dalby
# Processing Record 20 of Set 12 | nouakchott
# Processing Record 21 of Set 12 | palmer
# Processing Record 22 of Set 12 | la libertad
# Processing Record 23 of Set 12 | nome
# Processing Record 24 of Set 12 | fernandina beach
# Processing Record 25 of Set 12 | huicheng
# Processing Record 26 of Set 12 | shirokiy
# Processing Record 27 of Set 12 | thinadhoo
# Processing Record 28 of Set 12 | hurghada
# Processing Record 29 of Set 12 | ostrovnoy
# Processing Record 30 of Set 12 | shakhtinsk
# Processing Record 31 of Set 12 | kosh-agach
# Processing Record 32 of Set 12 | nicoya
# Processing Record 33 of Set 12 | imbituba
# Processing Record 34 of Set 12 | horki
# Processing Record 35 of Set 12 | waipawa
# Processing Record 36 of Set 12 | mayumba
# Processing Record 37 of Set 12 | vaitupu
# City not found. Skipping
# Processing Record 38 of Set 12 | salinopolis
# Processing Record 39 of Set 12 | okato
# Processing Record 40 of Set 12 | rawannawi
# City not found. Skipping
# Processing Record 41 of Set 12 | remedios
# Processing Record 42 of Set 12 | dzerzhinsk
# Processing Record 43 of Set 12 | toamasina
# Processing Record 44 of Set 12 | rangapara
# Processing Record 45 of Set 12 | la asuncion
# Processing Record 46 of Set 12 | lasa
# Processing Record 47 of Set 12 | qom
# Processing Record 48 of Set 12 | mindelo
# Processing Record 49 of Set 12 | grand-lahou
# Processing Record 50 of Set 12 | milagres
# Processing Record 1 of Set 13 | shushtar
# Processing Record 2 of Set 13 | palau
# Processing Record 3 of Set 13 | mildura
# Processing Record 4 of Set 13 | warqla
# City not found. Skipping
# Processing Record 5 of Set 13 | maghama
# City not found. Skipping
# Processing Record 6 of Set 13 | egvekinot
# Processing Record 7 of Set 13 | dingle
# Processing Record 8 of Set 13 | hami
# Processing Record 9 of Set 13 | amga
# Processing Record 10 of Set 13 | maues
# Processing Record 11 of Set 13 | ponta do sol
# Processing Record 12 of Set 13 | stevens point
# Processing Record 13 of Set 13 | makambako
# Processing Record 14 of Set 13 | buluang
# Processing Record 15 of Set 13 | zhanatas
# City not found. Skipping
# Processing Record 16 of Set 13 | zhanakorgan
# Processing Record 17 of Set 13 | road town
# Processing Record 18 of Set 13 | ruatoria
# City not found. Skipping
# Processing Record 19 of Set 13 | sungaipenuh
# Processing Record 20 of Set 13 | fare
# Processing Record 21 of Set 13 | turukhansk
# Processing Record 22 of Set 13 | sinkat
# City not found. Skipping
# Processing Record 23 of Set 13 | rehoboth
# Processing Record 24 of Set 13 | jambi
# Processing Record 25 of Set 13 | awbari
# Processing Record 26 of Set 13 | scottsburgh
# City not found. Skipping
# Processing Record 27 of Set 13 | micheweni
# Processing Record 28 of Set 13 | adolfo lopez mateos
# Processing Record 29 of Set 13 | san antero
# Processing Record 30 of Set 13 | asfi
# Processing Record 31 of Set 13 | sidi ali
# Processing Record 32 of Set 13 | terekli-mekteb
# Processing Record 33 of Set 13 | bolshiye uki
# City not found. Skipping
# Processing Record 34 of Set 13 | lolua
# City not found. Skipping
# Processing Record 35 of Set 13 | blagoyevo
# Processing Record 36 of Set 13 | jibuti
# Processing Record 37 of Set 13 | florianopolis
# Processing Record 38 of Set 13 | gangotri
# City not found. Skipping
# Processing Record 39 of Set 13 | oudtshoorn
# Processing Record 40 of Set 13 | pringsewu
# Processing Record 41 of Set 13 | russell
# Processing Record 42 of Set 13 | sao raimundo nonato
# Processing Record 43 of Set 13 | hohhot
# Processing Record 44 of Set 13 | takoradi
# Processing Record 45 of Set 13 | liseleje
# Processing Record 46 of Set 13 | dubbo
# Processing Record 47 of Set 13 | yerbogachen
# Processing Record 48 of Set 13 | genhe
# Processing Record 49 of Set 13 | qasigiannguit
# Processing Record 50 of Set 13 | acapulco
# Processing Record 1 of Set 14 | kawalu
# Processing Record 2 of Set 14 | ocos
# Processing Record 3 of Set 14 | sataua
# City not found. Skipping
# Processing Record 4 of Set 14 | shirgaon
# Processing Record 5 of Set 14 | auxerre
# Processing Record 6 of Set 14 | alta floresta
# Processing Record 7 of Set 14 | pangoa
# Processing Record 8 of Set 14 | ngukurr
# City not found. Skipping
# Processing Record 9 of Set 14 | sabang
# Processing Record 10 of Set 14 | santiago del estero
# Processing Record 11 of Set 14 | ajdabiya
# Processing Record 12 of Set 14 | linguere
# Processing Record 13 of Set 14 | cortes
# Processing Record 14 of Set 14 | bemidji
# Processing Record 15 of Set 14 | ugento
# Processing Record 16 of Set 14 | arteaga
# Processing Record 17 of Set 14 | sorland
# Processing Record 18 of Set 14 | sayyan
# Processing Record 19 of Set 14 | umm lajj
# Processing Record 20 of Set 14 | may pen
# Processing Record 21 of Set 14 | miquelon
# Processing Record 22 of Set 14 | viligili
# City not found. Skipping
# Processing Record 23 of Set 14 | salamanca
# Processing Record 24 of Set 14 | bela
# Processing Record 25 of Set 14 | banda aceh
# Processing Record 26 of Set 14 | west bay
# Processing Record 27 of Set 14 | simiti
# Processing Record 28 of Set 14 | barstow
# Processing Record 29 of Set 14 | nioro
# Processing Record 30 of Set 14 | puerto narino
# Processing Record 31 of Set 14 | thessalon
# Processing Record 32 of Set 14 | yumen
# Processing Record 33 of Set 14 | viradouro
# Processing Record 34 of Set 14 | new kensington
# Processing Record 35 of Set 14 | iralaya
# Processing Record 36 of Set 14 | port moresby
# Processing Record 37 of Set 14 | derzhavinsk
# Processing Record 38 of Set 14 | mareeba
# Processing Record 39 of Set 14 | puerto del rosario
# Processing Record 40 of Set 14 | kysyl-syr
# Processing Record 41 of Set 14 | slave lake
# Processing Record 42 of Set 14 | arman
# Processing Record 43 of Set 14 | mandla
# Processing Record 44 of Set 14 | arroyos y esteros
# Processing Record 45 of Set 14 | masunga
# Processing Record 46 of Set 14 | labutta
# City not found. Skipping
# Processing Record 47 of Set 14 | aitape
# Processing Record 48 of Set 14 | haines junction
# Processing Record 49 of Set 14 | kalabo
# Processing Record 50 of Set 14 | lata
# Processing Record 1 of Set 15 | lagoa
# Processing Record 2 of Set 15 | vanimo
# Processing Record 3 of Set 15 | cheney
# Processing Record 4 of Set 15 | hornepayne
# Processing Record 5 of Set 15 | bani walid
# Processing Record 6 of Set 15 | berlevag
# Processing Record 7 of Set 15 | deputatskiy
# Processing Record 8 of Set 15 | manavalakurichi
# Processing Record 9 of Set 15 | makakilo city
# Processing Record 10 of Set 15 | sur
# Processing Record 11 of Set 15 | churapcha
# Processing Record 12 of Set 15 | mercedes
# Processing Record 13 of Set 15 | denpasar
# Processing Record 14 of Set 15 | bjornevatn
# Processing Record 15 of Set 15 | freeport
# Processing Record 16 of Set 15 | maneadero
# Processing Record 17 of Set 15 | alto araguaia
# Processing Record 18 of Set 15 | rapid valley
# Processing Record 19 of Set 15 | luba
# Processing Record 20 of Set 15 | lukovetskiy
# Processing Record 21 of Set 15 | avera
# Processing Record 22 of Set 15 | turbat
# Processing Record 23 of Set 15 | pedernales
# Processing Record 24 of Set 15 | morant bay
# Processing Record 25 of Set 15 | stornoway
# Processing Record 26 of Set 15 | qandala
# Processing Record 27 of Set 15 | peace river
# Processing Record 28 of Set 15 | laguna
# Processing Record 29 of Set 15 | longlac
# City not found. Skipping
# Processing Record 30 of Set 15 | mayenne
# Processing Record 31 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 15 | kirovskiy
# Processing Record 33 of Set 15 | lauria
# Processing Record 34 of Set 15 | ancud
# Processing Record 35 of Set 15 | adre
# Processing Record 36 of Set 15 | hovd
# Processing Record 37 of Set 15 | solnechnyy
# Processing Record 38 of Set 15 | sobolevo
# Processing Record 39 of Set 15 | ivanteyevka
# Processing Record 40 of Set 15 | gigmoto
# Processing Record 41 of Set 15 | xinqing
# Processing Record 42 of Set 15 | arvi
# Processing Record 43 of Set 15 | asau
# Processing Record 44 of Set 15 | kalmunai
# Processing Record 45 of Set 15 | lincoln
# Processing Record 46 of Set 15 | loa janan
# Processing Record 47 of Set 15 | portoferraio
# Processing Record 48 of Set 15 | japura
# Processing Record 49 of Set 15 | ongandjera
# Processing Record 50 of Set 15 | ciudad bolivar
# Processing Record 1 of Set 16 | merauke
# Processing Record 2 of Set 16 | mikhaylovka
# Processing Record 3 of Set 16 | ha giang
# Processing Record 4 of Set 16 | udala
# Processing Record 5 of Set 16 | bida
# Processing Record 6 of Set 16 | karatuzskoye
# Processing Record 7 of Set 16 | mutsamudu
# City not found. Skipping
# Processing Record 8 of Set 16 | caxias
# Processing Record 9 of Set 16 | bystryy istok
# Processing Record 10 of Set 16 | westport
# Processing Record 11 of Set 16 | kungurtug
# Processing Record 12 of Set 16 | kainantu
# Processing Record 13 of Set 16 | gautier
# Processing Record 14 of Set 16 | asayita
# City not found. Skipping
# Processing Record 15 of Set 16 | jackson
# Processing Record 16 of Set 16 | salta
# Processing Record 17 of Set 16 | calvinia
# Processing Record 18 of Set 16 | neryungri
# Processing Record 19 of Set 16 | lodja
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Ilulissat      GL  2021-11-23 04:04:54  69.2167  -51.1000     17.62
# 1      Rikitea      PF  2021-11-23 04:04:55 -23.1203 -134.9692     75.90
# 2        Kapaa      US  2021-11-23 04:02:51  22.0752 -159.3190     80.58
# 3      Iquique      CL  2021-11-23 04:01:09 -20.2208  -70.1431     63.28
# 4  Tuktoyaktuk      CA  2021-11-23 04:00:35  69.4541 -133.0374     -6.50
# 5     Nhamunda      BR  2021-11-23 04:04:56  -2.1861  -56.7131     73.35
# 6         Poum      NC  2021-11-23 04:02:43 -20.2333  164.0167     78.33
# 7   Mahibadhoo      MV  2021-11-23 04:04:56   3.7833   72.9667     81.70
# 8        Arlit      NE  2021-11-23 04:03:34  18.7369    7.3853     70.30
# 9      Mosalsk      RU  2021-11-23 04:04:57  54.4881   34.9817     22.23
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        62          20       17.27          few clouds
# 1        76           1       11.36           clear sky
# 2        77          19        1.01          few clouds
# 3        72          98        1.97     overcast clouds
# 4        95         100        8.37     overcast clouds
# 5        97          95        0.92     overcast clouds
# 6        74         100        2.91     overcast clouds
# 7        73          99       16.80     overcast clouds
# 8        20           0        1.03           clear sky
# 9        87          99        4.16     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
